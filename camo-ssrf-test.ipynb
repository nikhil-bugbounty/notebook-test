# %%
camo_test
# Out:
# <img src="http://169.254.169.254/latest/meta-data/"><img src="http://127.0.0.1:9200/"><img src="http://[::1]:9200/"><img src="http://0x7f000001/"><img src="http://2852039166/">
