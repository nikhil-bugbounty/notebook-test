# %% [markdown]
# ![test](attachment:../../../etc/passwd)
# ![normal](attachment:normal.png)

# %% [raw]
# <script>alert(1)</script><img src=x onerror=alert(1)>

# %%
x
# Out:
# result

# %%
err
# Out:
# <img src=x onerror=alert(3)>
# <script>alert(4)</script>

# %%
widget
# Out:
# Widget
